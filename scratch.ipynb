# %%
import string
import re
puncts4re = fr'[{string.punctuation}\s]+'
puncts4re

re.split("[-\\s,]", "ash,r i-t,,y")
# Out:
# ['ash', 'r', 'i', 't', '', 'y']

# %%
s = list("he is good and is nice")
print(s)
# Out:
# ['h', 'e', ' ', 'i', 's', ' ', 'g', 'o', 'o', 'd', ' ', 'a', 'n', 'd', ' ', 'i', 's', ' ', 'n', 'i', 'c', 'e']

# %%
x = [1,24,45,55,3]

# %%
x = "hello"
t = "తె"
t2 = "త"
c = t2.encode("utf-8")
print(ord("త"))
print(c)
for k in c:
    print(k)
print("="*30)
c = t.encode("utf-8")
print(ord("త"))
print(c)
for k in c:
    print(k)

print(bytes([224,172, 134]).decode())
# print(bytes([172]).decode())
# print(ord("¬"))
oo = "¬".encode("utf-8")
print(oo)
for l in oo:
    print(l)
# Out:
# 3108
# b'\xe0\xb0\xa4'
# 224
# 176
# 164
# ...
# 3108
# b'\xe0\xb0\xa4\xe0\xb1\x86'
# 224
# 176
# 164
# 224
# 177
# 134
# ଆ
# b'\xc2\xac'
# 194
# 172

# %%
from typing import Dict, Tuple

def test(words: Dict[Tuple, int]):
    for w,f in words.items():
        print(w)

# %%
from collections import Counter

c = Counter()
c[tuple("the")] = 2
for w,f in c.items():
    print(w, f)
# Out:
# ('t', 'h', 'e') 2

# %%
import re
s = "<PAD>"
re.escape(s)
a = ["<PAD>", "<UNK>"]
p = re.compile('(' + '|'.join(a) + ')')
t = "hi how are you <PAD> can you give me this <PAD> <UNK>"
p.split(t)
# Out:
# ['hi how are you ',
#  '<PAD>',
#  ' can you give me this ',
#  '<PAD>',
#  ' ',
#  '<UNK>',
#  '']

# %%
training_text = "తెలుగు భాగవతం"
training_text = "భా"
[b for b in training_text.encode()]
# Out:
# [224, 176, 151]

# %%
a = (1,2)
c,b = a
print(c,b)
# Out:
# 1 2

# %%
import numpy as np

a = [
    [10, 3],
    [10, 1],
    [10, 8],
    [10, 4],
    [10, 7]
]
na = np.array(a)

np.where((na[:, 1] > 1))
# Out:
# (array([0, 2, 3, 4]),)

# %%
# matrix multiplication
import torch
A = torch.tensor([[1, 3, 5]])
B = torch.tensor([[2, 4, 5], 
                   [4, 6, 7],
                   [5, 6, 7]])

print(A @ B)
# print(B[0])

A[0][0] * B[0]

# r = 0
# for a,b in zip(A, B[0]):
#     r += a*b
# print(r)
# Out:
# tensor([[39, 52, 61]])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 11
#       8 print(A @ B)
#       9 # print(B[0])
# ---> 11 A[0][0].dot(B[0])
#      13 # r = 0
#      14 # for a,b in zip(A, B[0]):
#      15 #     r += a*b
#      16 # print(r)
#
# RuntimeError: 1D tensors expected, but got 0D and 1D tensors
